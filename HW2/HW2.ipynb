# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
data=pd.read_csv('games.data.csv')
data.head()
# Out:
#                             Name Platform  Year_of_Release   Genre  \
# 0  Grand Theft Auto: San Andreas      PS2           2004.0  Action
# 1                     Wii Sports      Wii           2006.0  Sports
# 2                 Gran Turismo 4      PS2           2004.0  Racing
# 3             Grand Theft Auto V      PS3           2013.0  Action
# 4                 Mario Kart Wii      Wii           2008.0  Racing
#
#                      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0         Take-Two Interactive      9.43      0.40      0.41        10.57
# 1                     Nintendo     41.36     28.96      3.77         8.45
# 2  Sony Computer Entertainment      3.01      0.01      1.10         7.53
# 3         Take-Two Interactive      7.02      9.09      0.98         3.96
# 4                     Nintendo     15.68     12.76      3.79         3.29
#
#    Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# ...

# %%
#遊戲平台排行圖表化
data=pd.read_csv('games.data.csv')

plat = data['Platform'].value_counts()
plat.plot.barh(figsize=(15,10), xlabel='Platform', title='Platform Ranking (per game)');

# %%
#發行年分圖表化
import matplotlib.font_manager as fm

plat = data['Year_of_Release'].value_counts()
plat.plot.bar(figsize=(15,10), xlabel='Year', title='Year_of_Release Ranking (per year)');

# %%
#找出哪個種類的遊戲出現最多次數
most_common_G = data['Genre'].value_counts().idxmax()
value_counts_G= data['Genre'].value_counts()


plat = data['Genre'].value_counts()
plat.plot.bar(figsize=(15,10), xlabel='Counts_of_Games', title='Genre_of_Games');

# %%
# 資料
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]

# 繪圖
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')

# 顯示圖表
plt.show()
