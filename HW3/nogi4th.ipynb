# %%
import urllib.request as req
import json
import pandas as pd
import numpy
from bs4 import BeautifulSoup
import requests
import webbrowser

# %%
urlfirst="https://www.nogizaka46.com/s/n46/artist/"
pages=range(55383,55398)
urlsec="?ima=2822"

for page in pages:
    link=urlfirst+str(page)+urlsec
    webbrowser.open(link)
    print(link)
# Out:
# https://www.nogizaka46.com/s/n46/artist/55383?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55384?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55385?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55386?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55387?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55388?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55389?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55390?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55391?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55392?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55393?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55394?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55395?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55396?ima=2822
# https://www.nogizaka46.com/s/n46/artist/55397?ima=2822

# %%
response=requests.get(link)
response.encoding='utf-8'
soup=BeautifulSoup(response.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ja">
# <head>
# <meta charset="utf-8"/>
# <script async="" data-wovnio="key=HQ9LiW" src="//j.wovn.io/1"></script>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,viewport-fit=cover" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="#fff" name="theme-color"/>
# <meta content="乃木坂46公式サイト" name="keyword">
# <meta content="「乃木坂46」のオフィシャルウェブサイト。最新の出演情報やスケジュール、メンバープロフィール、ディスコグラフィ、ライブ情報などを掲載しています。" name="description">
# <meta content="website" property="og:type"/>
# <meta content="乃木坂46公式サイト" property="og:title"/>
# <meta content="乃木坂46公式サイト" property="og:site_name"/>
# <meta content="「乃木坂46」のオフィシャルウェブサイト。最新の出演情報やスケジュール、メンバープロフィール、ディスコグラフィ、ライブ情報などを掲載しています。" property="og:description"/>
# <meta content="https://www.nogizaka46.com/" property="og:url"/>
# ...

# %%
titles = []


for page in pages:
    link = urlfirst + str(page) + urlsec
    response = requests.get(link)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, "html.parser")
    title_tags = soup.find_all(class_='md--hd__ttl f--head a--tx js-tdi js-membername')
    for title in title_tags:
        titles.append(title.text)
#55388沒有人
for title in titles:
    print(title)
# Out:
# 黒見 明香
# 佐藤 璃果
# 林 瑠奈
# 松尾 美佑
# 弓木 奈於
# 井上 和
# 一ノ瀬 美空
# 菅原 咲月
# 小川 彩
# 冨里 奈央
# 奥田 いろは
# 中西 アルノ
# 五百城 茉央
# 池田 瑛紗
